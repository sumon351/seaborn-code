# %% [markdown]
# # barplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# collect data from seaborn data set (github)
df=sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.barplot(x='island',y='bill_length_mm',data=df)
plt.show()

# %%
# using hue parameter for separated
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex')
plt.title('barplot')
plt.show()

# %%
# using order parameter
order1=['Dream','Torgersen','Biscoe']
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',order=order1)
plt.title('barplot')
plt.show()

# %%
# changing bar (female than male) through the hue parameter
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'])
plt.title('barplot')
plt.show()

# %%
# changing the interval line through the (ci) parameter and it has range (0 to 100)
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],ci=100)
plt.title('barplot')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\152992421.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],ci=100)

# %%
# changing the interval line through the (ci) parameter and it has range (0 to 100)
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],ci=0)
plt.title('barplot')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\223627870.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],ci=0)

# %%
# changing the interval line through the (ci) parameter and it has range (0 to 100)
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],ci=33)
plt.title('barplot')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\242955640.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 33)` for the same effect.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],ci=33)

# %%
# using orientation for horizontal
sns.barplot(x='island',y='bill_length_mm',data=df,orient='h')
plt.title('barplot')
plt.show()

# %%
sns.barplot(x='island',y='bill_length_mm',data=df,color='b')
plt.show()

# %%
# using palette parameter for color
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire')
plt.title('barplot')
plt.show()

# %%
# using palette parameter for color with saturation
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',
            saturation=0.2)
plt.title('barplot')
plt.show()

# %%
# error color and error with (interval line)
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',
            errcolor='k',errwidth='4')
plt.title('barplot')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\2374188016.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'k'}` instead.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\2374188016.py:2: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': '4'}` instead.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',

# %%
#capsize(remember boxplot)
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',
            errcolor='b',capsize=0.5)
plt.title('barplot')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\2240802159.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'b'}` instead.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',

# %%
# using darkgrid and alpha parameter
sns.set(style='darkgrid')
sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',
            errcolor='b',alpha=0.7)
plt.title('barplot')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6592\768095333.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'b'}` instead.
#
#   sns.barplot(x='island',y='bill_length_mm',data=df,hue='sex',hue_order=['Female','Male'],palette='icefire',
